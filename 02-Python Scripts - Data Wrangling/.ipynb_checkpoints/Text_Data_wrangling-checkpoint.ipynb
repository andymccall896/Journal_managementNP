# %% [markdown]
# # Import Packages

# %%
#Data wrangling package in Python 
import pandas as pd
#
import numpy as np
#Glob pythons filepath recognition 
import glob 
# Pythons package is the way in which it can interact with the operating system
import os
# natural language processing package 
import nltk 
import re
#R               | Pandas
#-------------------------------
#summary(df)     | df.describe()
#head(df)        | df.head()
#dim(df)         | df.shape
#slice(df, 1:10) | df.iloc[:9]
#os.chdir("C:/Users/andym/Desktop/Datafancy/Journal_managementNP/01-Raw_data/all_data")
#print(glob.glob("/home/adam/*.txt"))
#all_files = glob.glob(path + "/*.csv")
from nltk.stem import PorterStemmer 
from nltk.tokenize import word_tokenize 
from nltk.stem import PorterStemmer
from nltk.stem import LancasterStemmer   
ps = PorterStemmer() 
porter = PorterStemmer()
lancaster=LancasterStemmer()
#proide a word to be stemmed
#print("Porter Stemmer")
#print(porter.stem("cats"))
#print(porter.stem("trouble"))
#print(porter.stem("troubling"))
#print(porter.stem("troubled"))
#print("Lancaster Stemmer")
#print(lancaster.stem("cats"))
#print(lancaster.stem("trouble"))
#print(lancaster.stem("troubling"))
#print(lancaster.stem("troubled"))

# %% [markdown]
# #### Collate all CSV files together

# %%
print(glob.glob("/home/adam/*.txt"))
os.chdir("C:/Users/andym/Desktop/Datafancy/Journal_managementNP/01-Raw_data/all_data")
# get data file names
path =r'C:\Users\andym\Desktop\Datafancy\Knowledge Discovery -DL\01-Raw_data\all_data'
all_files = glob.glob(path + "/*.csv")

### set an empty list?
li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    df['file_name'] = filename
    li.append(df)
    
frame = pd.concat(li, axis=0, ignore_index=True)
dframe = pd.DataFrame(data = frame)
dframe['Publication Year'] = dframe['Publication Year'].astype('int')
# Out:
# []
#                   Lens ID                                              Title  \
# 0     001-293-329-888-964  F. Bartelt: Authority lists for the assignment...
# 1     001-763-825-075-165           Studien zur allgemeinen Ordnungslehre. I
# 2     001-798-785-843-501  Deutscher Dokumentartag 1977. („Intentions and...
# 3     006-385-209-392-26X     Lancaster: Vocabulary Control ... (D. Soergel)
# 4     006-620-125-685-134   Citation codes in classification and terminology
# ...                   ...                                                ...
# 1824  173-831-542-301-475                           Books Recently Published
# 1825  173-877-453-721-519   Semantic Enrichment of Linked Archival Materials
# 1826  187-066-432-753-22X                                          Impressum
# 1827  187-701-961-076-877                           Mapping the KO Community
# 1828  192-242-542-397-722                                Peer Review in 2018
#
#      Date Published  Publication Year Publication Type  \
# 0               NaN              1979  journal article
# 1               NaN              1974  journal article
# 2               NaN              1978  journal article
# 3               NaN              1975  journal article
# 4               NaN              1978  journal article
# ...             ...               ...              ...
# 1824            NaN              2020  journal article
# 1825            NaN              2019  journal article
# 1826            NaN              2020  journal article
# 1827     2019-09-23              2019  journal article
# 1828            NaN              2019  journal article
#
#                 Source Title    ISSNs  \
# 0     KNOWLEDGE ORGANIZATION  9437444
# 1     Knowledge Organization  9437444
# 2     KNOWLEDGE ORGANIZATION  9437444
# 3     KNOWLEDGE ORGANIZATION  9437444
# 4     Knowledge Organization  9437444
# ...                      ...      ...
# 1824  KNOWLEDGE ORGANIZATION  9437444
# 1825  Knowledge Organization  9437444
# 1826  KNOWLEDGE ORGANIZATION  9437444
# 1827  Knowledge Organization  9437444
# 1828  KNOWLEDGE ORGANIZATION  9437444
#
#                                              Publisher Source Country  \
# 0                                         Nomos Verlag            NaN
# 1     International Society for Knowledge Organization        Germany
# 2                                         Nomos Verlag            NaN
# 3                                         Nomos Verlag            NaN
# 4     International Society for Knowledge Organization        Germany
# ...                                                ...            ...
# 1824                                      Nomos Verlag            NaN
# 1825  International Society for Knowledge Organization        Germany
# 1826                                      Nomos Verlag            NaN
# 1827  International Society for Knowledge Organization        Germany
# 1828                                      Nomos Verlag            NaN
#
#                                     Author/s  ...  \
# 0                                        NaN  ...
# 1                               Alwin Diemer  ...
# 2                                        NaN  ...
# 3                                        NaN  ...
# 4                         Ingetraut Dahlberg  ...
# ...                                      ...  ...
# 1824                                     NaN  ...
# 1825                           Shu-Jiun Chen  ...
# 1826                                     NaN  ...
# 1827  Heather Moulaison Sandy; Andrew Dillon  ...
# 1828                                     NaN  ...
#
#                                             Source URLs  \
# 0                                                   NaN
# 1         http://dx.doi.org/10.5771/0943-7444-1974-2-61
# 2                                                   NaN
# 3                                                   NaN
# 4         http://dx.doi.org/10.5771/0943-7444-1978-2-91
# ...                                                 ...
# 1824                                                NaN
# 1825     http://dx.doi.org/10.5771/0943-7444-2019-7-530
# 1826                                                NaN
# 1827  https://journals.lib.washington.edu/index.php/...
# 1828                                                NaN
#
#                                            External URL PMID  \
# 0        http://dx.doi.org/10.5771/0943-7444-1979-3-187  NaN
# 1         http://dx.doi.org/10.5771/0943-7444-1974-2-61  NaN
# 2        http://dx.doi.org/10.5771/0943-7444-1978-3-178  NaN
# 3         http://dx.doi.org/10.5771/0943-7444-1975-1-51  NaN
# 4         http://dx.doi.org/10.5771/0943-7444-1978-2-91  NaN
# ...                                                 ...  ...
# 1824     http://dx.doi.org/10.5771/0943-7444-2020-4-364  NaN
# 1825     http://dx.doi.org/10.5771/0943-7444-2019-7-530  NaN
# 1826     http://dx.doi.org/10.5771/0943-7444-2020-3-280  NaN
# 1827  https://journals.lib.washington.edu/index.php/...  NaN
# 1828       http://dx.doi.org/10.5771/0943-7444-2019-1-3  NaN
#
#                                DOI Microsoft Academic ID PMCID  \
# 0     10.5771/0943-7444-1979-3-187                   NaN   NaN
# 1      10.5771/0943-7444-1974-2-61          2.892327e+09   NaN
# 2     10.5771/0943-7444-1978-3-178                   NaN   NaN
# 3      10.5771/0943-7444-1975-1-51                   NaN   NaN
# 4      10.5771/0943-7444-1978-2-91          2.892007e+09   NaN
# ...                            ...                   ...   ...
# 1824  10.5771/0943-7444-2020-4-364                   NaN   NaN
# 1825  10.5771/0943-7444-2019-7-530          2.999898e+09   NaN
# 1826  10.5771/0943-7444-2020-3-280                   NaN   NaN
# 1827                           NaN          2.972827e+09   NaN
# 1828    10.5771/0943-7444-2019-1-3                   NaN   NaN
#
#       Patent Citation Count  References  Scholarly Citation Count  \
# 0                         0         NaN                         0
# 1                         0         NaN                         0
# 2                         0         NaN                         0
# 3                         0         NaN                         0
# 4                         0         NaN                         0
# ...                     ...         ...                       ...
# 1824                      0         NaN                         0
# 1825                      0         NaN                         0
# 1826                      0         NaN                         0
# 1827                      0         NaN                         0
# 1828                      0         NaN                         0
#
#                                               file_name
# 0     C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
# 1     C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
# 2     C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
# 3     C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
# 4     C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
# ...                                                 ...
# 1824  C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
# 1825  C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
# 1826  C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
# 1827  C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
# 1828  C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
#
# [1829 rows x 30 columns]

# %%
#### Playing with the stop words functions
from nltk.corpus import stopwords
englishstopwords = stopwords.words('english')
print(englishstopwords)
#### lower case it first
#### iterate through the dataframe and see if abstract has any of these words
#### make sure the abstract is turned into a list 
#### think logically what you want to do
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %% [markdown]
# #### inspect Dataframe

# %%
#dframe.dtypes
df
# Out:
#                  Lens ID                                              Title  \
# 0    001-080-711-016-033                         Titelei/Inhaltsverzeichnis
# 1    002-227-810-181-405                                    Alphabetization
# 2    002-609-873-058-352  Knowledge Ontology: A Tool for the Unification...
# 3    004-621-144-103-672          Explainable AI: Linking Human and Machine
# 4    005-946-351-440-796                                                NaN
# ..                   ...                                                ...
# 118  173-831-542-301-475                           Books Recently Published
# 119  173-877-453-721-519   Semantic Enrichment of Linked Archival Materials
# 120  187-066-432-753-22X                                          Impressum
# 121  187-701-961-076-877                           Mapping the KO Community
# 122  192-242-542-397-722                                Peer Review in 2018
#
#     Date Published  Publication Year Publication Type            Source Title  \
# 0              NaN              2019  journal article  KNOWLEDGE ORGANIZATION
# 1              NaN              2019  journal article  KNOWLEDGE ORGANIZATION
# 2              NaN              2019  journal article  Knowledge Organization
# 3              NaN              2019  journal article  Knowledge Organization
# 4              NaN              2020    journal issue  KNOWLEDGE ORGANIZATION
# ..             ...               ...              ...                     ...
# 118            NaN              2020  journal article  KNOWLEDGE ORGANIZATION
# 119            NaN              2019  journal article  Knowledge Organization
# 120            NaN              2020  journal article  KNOWLEDGE ORGANIZATION
# 121     2019-09-23              2019  journal article  Knowledge Organization
# 122            NaN              2019  journal article  KNOWLEDGE ORGANIZATION
#
#        ISSNs                                         Publisher Source Country  \
# 0    9437444                                      Nomos Verlag            NaN
# 1    9437444                                      Nomos Verlag            NaN
# 2    9437444  International Society for Knowledge Organization        Germany
# 3    9437444  International Society for Knowledge Organization        Germany
# 4    9437444                                      Nomos Verlag            NaN
# ..       ...                                               ...            ...
# 118  9437444                                      Nomos Verlag            NaN
# 119  9437444  International Society for Knowledge Organization        Germany
# 120  9437444                                      Nomos Verlag            NaN
# 121  9437444  International Society for Knowledge Organization        Germany
# 122  9437444                                      Nomos Verlag            NaN
#
#                                    Author/s  ...  \
# 0                                       NaN  ...
# 1                 Wendy Korwin; Haakon Lund  ...
# 2                               Guohua Xiao  ...
# 3                               Guohua Xiao  ...
# 4                                       NaN  ...
# ..                                      ...  ...
# 118                                     NaN  ...
# 119                           Shu-Jiun Chen  ...
# 120                                     NaN  ...
# 121  Heather Moulaison Sandy; Andrew Dillon  ...
# 122                                     NaN  ...
#
#                                            Source URLs  \
# 0                                                  NaN
# 1                                                  NaN
# 2       http://dx.doi.org/10.5771/0943-7444-2019-3-236
# 3       http://dx.doi.org/10.5771/0943-7444-2019-5-398
# 4                                                  NaN
# ..                                                 ...
# 118                                                NaN
# 119     http://dx.doi.org/10.5771/0943-7444-2019-7-530
# 120                                                NaN
# 121  https://journals.lib.washington.edu/index.php/...
# 122                                                NaN
#
#                                           External URL  PMID  \
# 0         http://dx.doi.org/10.5771/0943-7444-2019-2-i   NaN
# 1       http://dx.doi.org/10.5771/0943-7444-2019-3-209   NaN
# 2       http://dx.doi.org/10.5771/0943-7444-2019-3-236   NaN
# 3       http://dx.doi.org/10.5771/0943-7444-2019-5-398   NaN
# 4           http://dx.doi.org/10.5771/0943-7444-2020-3   NaN
# ..                                                 ...   ...
# 118     http://dx.doi.org/10.5771/0943-7444-2020-4-364   NaN
# 119     http://dx.doi.org/10.5771/0943-7444-2019-7-530   NaN
# 120     http://dx.doi.org/10.5771/0943-7444-2020-3-280   NaN
# 121  https://journals.lib.washington.edu/index.php/...   NaN
# 122       http://dx.doi.org/10.5771/0943-7444-2019-1-3   NaN
#
#                               DOI Microsoft Academic ID PMCID  \
# 0      10.5771/0943-7444-2019-2-i                   NaN   NaN
# 1    10.5771/0943-7444-2019-3-209                   NaN   NaN
# 2    10.5771/0943-7444-2019-3-236          2.955642e+09   NaN
# 3    10.5771/0943-7444-2019-5-398          2.969989e+09   NaN
# 4        10.5771/0943-7444-2020-3                   NaN   NaN
# ..                            ...                   ...   ...
# 118  10.5771/0943-7444-2020-4-364                   NaN   NaN
# 119  10.5771/0943-7444-2019-7-530          2.999898e+09   NaN
# 120  10.5771/0943-7444-2020-3-280                   NaN   NaN
# 121                           NaN          2.972827e+09   NaN
# 122    10.5771/0943-7444-2019-1-3                   NaN   NaN
#
#      Patent Citation Count  References  Scholarly Citation Count  \
# 0                        0         NaN                         0
# 1                        0         NaN                         0
# 2                        0         NaN                         1
# 3                        0         NaN                         0
# 4                        0         NaN                         0
# ..                     ...         ...                       ...
# 118                      0         NaN                         0
# 119                      0         NaN                         0
# 120                      0         NaN                         0
# 121                      0         NaN                         0
# 122                      0         NaN                         0
#
#                                              file_name
# 0    C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
# 1    C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
# 2    C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
# 3    C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
# 4    C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
# ..                                                 ...
# 118  C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
# 119  C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
# 120  C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
# 121  C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
# 122  C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
#
# [123 rows x 30 columns]

# %% [markdown]
# #### Converting Variables

# %%
#### Covert the publication year to integer 
dframe['Publication Year'] = dframe['Publication Year'].astype('int') 

#### Filter out the null values in the Abstract 
dframetrim = dframe[dframe.Abstract.notnull()]

# %% [markdown]
# #### Tutorial on removing stop words and other NLTK functions

# %%
#### removing any abstracts with a null value in it. 
#### look into how to turn one abstract row to a list
#### This is just a testing cell 
from nltk.corpus import stopwords
from nltk.corpus import stopwords
englishstopwords = stopwords.words('english')
print(englishstopwords)
#examples
text = "Nick likes to play football, however he is not too fond of tennis."
text_tokens = word_tokenize(text)
tokens_without_sw = [word for word in text_tokens if not word in stopwords.words()]
print(tokens_without_sw)

dframe['Abstract']
dframetrim['Abstract'].values[0].lower()

#### Removing special characters
#### I also need to remove full stops and commas
test = re.sub('[^A-Za-z0-9]+', ' ', dframetrim['Abstract'].values[0].lower())
text = test.split(' ')
text

filtered_words = [word for word in text if word not in stopwords.words('english')]
filtered_words
text
dframetrim['Abstract'].values[0].lower()

###### Now to apply to stemming
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
# ['Nick', 'likes', 'play', 'football', ',', 'however', 'fond', 'tennis', '.']
# 'the real challenge of today lies in exploring how computers will enable us to do what was not possible previously. the paper attempts to provoke thought about new frontiers of visual knowledge organization. computers introduce the possibility of interchangeable media. they offer multiple nodes of access to a given term or object. they enable us to approach knowledge on different levels. a scheme of 10 levels is proposed and some consequences for visual knowledge at each of these levels is considered briefly. the final section of the paper considers four navigational tools: questions, maps, meters, and tracking'

# %% [markdown]
# #### Lambda functions to iterate over each row and converting to a list

# %%
##### Using a for loop to iterate through each row 
##### This is very strange why it works now. 
dframetrim['Abstract_trim_2'] = dframetrim['Abstract']

for i in range(len(dframetrim['Abstract'])):
    dframetrim['Abstract_trim_2'].values[i]  = re.sub('[^A-Za-z0-9]+', ' ', dframetrim['Abstract_trim_2'].values[i].lower()) ## Lower case and special characters removed
    dframetrim['Abstract_trim_2'].values[i]  = dframetrim['Abstract_trim_2'].values[i].split(' ') ## tokenise
##### I might need to look up lambda
dframetrim['Abstract_trim_2'] = dframetrim['Abstract_trim_2'].apply(lambda x: [item for item in x if item not in stopwords.words('english')]) ## Stopwords
dframetrim['Abstract_trim_2'] =  dframetrim['Abstract_trim_2'].apply(lambda x: [porter.stem(item) for item in x ]) ## Stemming 
dframetrim
# Out:
# C:\Users\andym\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\andym\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\andym\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
#                   Lens ID                                              Title  \
# 621   000-251-444-646-256              Electronic media and visual knowledge
# 623   002-768-931-855-543  HYPERICONICS: Hypertext and the social constru...
# 627   013-996-415-887-147         Terminological research in the former USSR
# 631   017-489-591-364-184  Seven fundamental questions for the science of...
# 638   025-077-447-234-296  Subject authory control in a union catalogue: ...
# ...                   ...                                                ...
# 1811  145-162-485-543-214              Episemantics: Aboutness as Aroundness
# 1813  145-286-664-702-879  Facet Analysis of Anime Genres: The Challenges...
# 1818  152-347-604-820-830            The Basic Concepts Classification (BCC)
# 1825  173-877-453-721-519   Semantic Enrichment of Linked Archival Materials
# 1827  187-701-961-076-877                           Mapping the KO Community
#
#      Date Published  Publication Year Publication Type  \
# 621             NaN              1993  journal article
# 623             NaN              1993  journal article
# 627             NaN              1993  journal article
# 631      1993-12-01              1993  journal article
# 638             NaN              1993  journal article
# ...             ...               ...              ...
# 1811            NaN              2019  journal article
# 1813            NaN              2020  journal article
# 1818     2020-07-09              2020  journal article
# 1825            NaN              2019  journal article
# 1827     2019-09-23              2019  journal article
#
#                 Source Title    ISSNs  \
# 621   Knowledge Organization  9437444
# 623   Knowledge Organization  9437444
# 627   Knowledge Organization  9437444
# 631   Knowledge Organization  9437444
# 638   Knowledge Organization  9437444
# ...                      ...      ...
# 1811  KNOWLEDGE ORGANIZATION  9437444
# 1813  KNOWLEDGE ORGANIZATION  9437444
# 1818  Knowledge Organization  9437444
# 1825  Knowledge Organization  9437444
# 1827  Knowledge Organization  9437444
#
#                                              Publisher Source Country  \
# 621   International Society for Knowledge Organization        Germany
# 623   International Society for Knowledge Organization        Germany
# 627   International Society for Knowledge Organization        Germany
# 631   International Society for Knowledge Organization        Germany
# 638   International Society for Knowledge Organization        Germany
# ...                                                ...            ...
# 1811                                      Nomos Verlag        Germany
# 1813                                      Nomos Verlag            NaN
# 1818  International Society for Knowledge Organization        Germany
# 1825  International Society for Knowledge Organization        Germany
# 1827  International Society for Knowledge Organization        Germany
#
#                                                Author/s  ...  \
# 621                                      Kim H. Veltman  ...
# 623                                   Gerhard Jan Nauta  ...
# 627                                     Sergey V.Grinev  ...
# 631                                     Robert M. Losee  ...
# 638                                    Maria Ines Lopes  ...
# ...                                                 ...  ...
# 1811                   Elliott Hauser; Joseph T. Tennis  ...
# 1813  Hyerim Cho; Thomas Disher; Wan-Chen Lee; Steph...  ...
# 1818                                       Rick Szostak  ...
# 1825                                      Shu-Jiun Chen  ...
# 1827             Heather Moulaison Sandy; Andrew Dillon  ...
#
#                                            External URL  PMID  \
# 621       http://dx.doi.org/10.5771/0943-7444-1993-1-47   NaN
# 623       http://dx.doi.org/10.5771/0943-7444-1993-1-35   NaN
# 627      http://dx.doi.org/10.5771/0943-7444-1993-3-150   NaN
# 631       http://dx.doi.org/10.5771/0943-7444-1993-2-65   NaN
# 638      http://dx.doi.org/10.5771/0943-7444-1993-3-133   NaN
# ...                                                 ...   ...
# 1811     http://dx.doi.org/10.5771/0943-7444-2019-8-590   NaN
# 1813      http://dx.doi.org/10.5771/0943-7444-2020-1-13   NaN
# 1818     http://dx.doi.org/10.5771/0943-7444-2020-3-231   NaN
# 1825     http://dx.doi.org/10.5771/0943-7444-2019-7-530   NaN
# 1827  https://journals.lib.washington.edu/index.php/...   NaN
#
#                                DOI Microsoft Academic ID PMCID  \
# 621    10.5771/0943-7444-1993-1-47          2.495233e+09   NaN
# 623    10.5771/0943-7444-1993-1-35          2.505692e+09   NaN
# 627   10.5771/0943-7444-1993-3-150          2.475052e+09   NaN
# 631    10.5771/0943-7444-1993-2-65          5.290351e+07   NaN
# 638   10.5771/0943-7444-1993-3-133          2.469551e+09   NaN
# ...                            ...                   ...   ...
# 1811  10.5771/0943-7444-2019-8-590                   NaN   NaN
# 1813   10.5771/0943-7444-2020-1-13                   NaN   NaN
# 1818  10.5771/0943-7444-2020-3-231          3.041962e+09   NaN
# 1825  10.5771/0943-7444-2019-7-530          2.999898e+09   NaN
# 1827                           NaN          2.972827e+09   NaN
#
#      Patent Citation Count                                         References  \
# 621                      0                                188-563-904-203-247
# 623                      0                                                NaN
# 627                      0                                                NaN
# 631                      0  005-255-725-462-840; 010-656-047-738-040; 016-...
# 638                      0                                                NaN
# ...                    ...                                                ...
# 1811                     0                                                NaN
# 1813                     0                                                NaN
# 1818                     0                                                NaN
# 1825                     0                                                NaN
# 1827                     0                                                NaN
#
#       Scholarly Citation Count  \
# 621                          1
# 623                          0
# 627                          0
# 631                         10
# 638                          0
# ...                        ...
# 1811                         0
# 1813                         0
# 1818                         0
# 1825                         0
# 1827                         0
#
#                                               file_name  \
# 621   C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
# 623   C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
# 627   C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
# 631   C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
# 638   C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
# ...                                                 ...
# 1811  C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
# 1813  C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
# 1818  C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
# 1825  C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
# 1827  C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
#
#                                         Abstract_trim_2
# 621   [real, challeng, today, lie, explor, comput, e...
# 623   [25, year, ago, leiden, art, historian, van, d...
# 627   [outlin, short, histori, terminolog, former, u...
# 631   [classif, advanc, point, optim, system, may, d...
# 638   [1989, exist, onlin, union, catalogu, nation, ...
# ...                                                 ...
# 1811  [, p, about, rank, amongst, field, greatest, b...
# 1813                                            [, p, ]
# 1818  [, p, basic, concept, classif, bcc, univers, s...
# 1825  [, p, use, metadata, fond, chen, cheng, po, pa...
# 1827  [knowledg, organ, ko, consid, distinct, discip...
#
# [360 rows x 31 columns]

# %%
##### This is something that needs to be spot checked. 

dframetrim['Abstract_trim_2'].values[5]
#dframetrim['Abstract_trim'].values[5]
# Out:
# ['effort',
#  'build',
#  'virtual',
#  'museum',
#  'focuss',
#  'predominantli',
#  'solv',
#  'problem',
#  'rapid',
#  'chang',
#  'interfac',
#  'technolog',
#  'insuffici',
#  'effort',
#  'spent',
#  'plan',
#  'virtual',
#  'databas',
#  'multimedia',
#  'environ',
#  'depend',
#  'particularli',
#  'viewpoint',
#  'scholarli',
#  'research',
#  'getti',
#  'art',
#  'histori',
#  'inform',
#  'program',
#  'develop',
#  'vocabulari',
#  'encourag',
#  'consist',
#  'among',
#  'scholarli',
#  'document',
#  'project',
#  'regardless',
#  'technic',
#  'implement',
#  'terminolog',
#  'standard',
#  'two',
#  'vocabulari',
#  'intend',
#  'control',
#  'terminolog',
#  'point',
#  'data',
#  'captur',
#  'describ',
#  'scenario',
#  'propos',
#  'util',
#  'navig',
#  'complex',
#  'databas',
#  'underli',
#  'virtual',
#  'museum']

# %%
dframetrim
# Out:
#                   Lens ID                                              Title  \
# 621   000-251-444-646-256              Electronic media and visual knowledge
# 623   002-768-931-855-543  HYPERICONICS: Hypertext and the social constru...
# 627   013-996-415-887-147         Terminological research in the former USSR
# 631   017-489-591-364-184  Seven fundamental questions for the science of...
# 638   025-077-447-234-296  Subject authory control in a union catalogue: ...
# ...                   ...                                                ...
# 1811  145-162-485-543-214              Episemantics: Aboutness as Aroundness
# 1813  145-286-664-702-879  Facet Analysis of Anime Genres: The Challenges...
# 1818  152-347-604-820-830            The Basic Concepts Classification (BCC)
# 1825  173-877-453-721-519   Semantic Enrichment of Linked Archival Materials
# 1827  187-701-961-076-877                           Mapping the KO Community
#
#      Date Published  Publication Year Publication Type  \
# 621             NaN              1993  journal article
# 623             NaN              1993  journal article
# 627             NaN              1993  journal article
# 631      1993-12-01              1993  journal article
# 638             NaN              1993  journal article
# ...             ...               ...              ...
# 1811            NaN              2019  journal article
# 1813            NaN              2020  journal article
# 1818     2020-07-09              2020  journal article
# 1825            NaN              2019  journal article
# 1827     2019-09-23              2019  journal article
#
#                 Source Title    ISSNs  \
# 621   Knowledge Organization  9437444
# 623   Knowledge Organization  9437444
# 627   Knowledge Organization  9437444
# 631   Knowledge Organization  9437444
# 638   Knowledge Organization  9437444
# ...                      ...      ...
# 1811  KNOWLEDGE ORGANIZATION  9437444
# 1813  KNOWLEDGE ORGANIZATION  9437444
# 1818  Knowledge Organization  9437444
# 1825  Knowledge Organization  9437444
# 1827  Knowledge Organization  9437444
#
#                                              Publisher Source Country  \
# 621   International Society for Knowledge Organization        Germany
# 623   International Society for Knowledge Organization        Germany
# 627   International Society for Knowledge Organization        Germany
# 631   International Society for Knowledge Organization        Germany
# 638   International Society for Knowledge Organization        Germany
# ...                                                ...            ...
# 1811                                      Nomos Verlag        Germany
# 1813                                      Nomos Verlag            NaN
# 1818  International Society for Knowledge Organization        Germany
# 1825  International Society for Knowledge Organization        Germany
# 1827  International Society for Knowledge Organization        Germany
#
#                                                Author/s  ...  \
# 621                                      Kim H. Veltman  ...
# 623                                   Gerhard Jan Nauta  ...
# 627                                     Sergey V.Grinev  ...
# 631                                     Robert M. Losee  ...
# 638                                    Maria Ines Lopes  ...
# ...                                                 ...  ...
# 1811                   Elliott Hauser; Joseph T. Tennis  ...
# 1813  Hyerim Cho; Thomas Disher; Wan-Chen Lee; Steph...  ...
# 1818                                       Rick Szostak  ...
# 1825                                      Shu-Jiun Chen  ...
# 1827             Heather Moulaison Sandy; Andrew Dillon  ...
#
#                                            External URL  PMID  \
# 621       http://dx.doi.org/10.5771/0943-7444-1993-1-47   NaN
# 623       http://dx.doi.org/10.5771/0943-7444-1993-1-35   NaN
# 627      http://dx.doi.org/10.5771/0943-7444-1993-3-150   NaN
# 631       http://dx.doi.org/10.5771/0943-7444-1993-2-65   NaN
# 638      http://dx.doi.org/10.5771/0943-7444-1993-3-133   NaN
# ...                                                 ...   ...
# 1811     http://dx.doi.org/10.5771/0943-7444-2019-8-590   NaN
# 1813      http://dx.doi.org/10.5771/0943-7444-2020-1-13   NaN
# 1818     http://dx.doi.org/10.5771/0943-7444-2020-3-231   NaN
# 1825     http://dx.doi.org/10.5771/0943-7444-2019-7-530   NaN
# 1827  https://journals.lib.washington.edu/index.php/...   NaN
#
#                                DOI Microsoft Academic ID PMCID  \
# 621    10.5771/0943-7444-1993-1-47          2.495233e+09   NaN
# 623    10.5771/0943-7444-1993-1-35          2.505692e+09   NaN
# 627   10.5771/0943-7444-1993-3-150          2.475052e+09   NaN
# 631    10.5771/0943-7444-1993-2-65          5.290351e+07   NaN
# 638   10.5771/0943-7444-1993-3-133          2.469551e+09   NaN
# ...                            ...                   ...   ...
# 1811  10.5771/0943-7444-2019-8-590                   NaN   NaN
# 1813   10.5771/0943-7444-2020-1-13                   NaN   NaN
# 1818  10.5771/0943-7444-2020-3-231          3.041962e+09   NaN
# 1825  10.5771/0943-7444-2019-7-530          2.999898e+09   NaN
# 1827                           NaN          2.972827e+09   NaN
#
#      Patent Citation Count                                         References  \
# 621                      0                                188-563-904-203-247
# 623                      0                                                NaN
# 627                      0                                                NaN
# 631                      0  005-255-725-462-840; 010-656-047-738-040; 016-...
# 638                      0                                                NaN
# ...                    ...                                                ...
# 1811                     0                                                NaN
# 1813                     0                                                NaN
# 1818                     0                                                NaN
# 1825                     0                                                NaN
# 1827                     0                                                NaN
#
#       Scholarly Citation Count  \
# 621                          1
# 623                          0
# 627                          0
# 631                         10
# 638                          0
# ...                        ...
# 1811                         0
# 1813                         0
# 1818                         0
# 1825                         0
# 1827                         0
#
#                                               file_name  \
# 621   C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
# 623   C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
# 627   C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
# 631   C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
# 638   C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
# ...                                                 ...
# 1811  C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
# 1813  C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
# 1818  C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
# 1825  C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
# 1827  C:\Users\andym\Desktop\Datafancy\Knowledge Dis...
#
#                                         Abstract_trim_2
# 621   [real, challeng, today, lie, explor, comput, e...
# 623   [25, year, ago, leiden, art, historian, van, d...
# 627   [outlin, short, histori, terminolog, former, u...
# 631   [classif, advanc, point, optim, system, may, d...
# 638   [1989, exist, onlin, union, catalogu, nation, ...
# ...                                                 ...
# 1811  [, p, about, rank, amongst, field, greatest, b...
# 1813                                            [, p, ]
# 1818  [, p, basic, concept, classif, bcc, univers, s...
# 1825  [, p, use, metadata, fond, chen, cheng, po, pa...
# 1827  [knowledg, organ, ko, consid, distinct, discip...
#
# [360 rows x 31 columns]

# %% [markdown]
# #### Playing with stemming functions from NLTK

# %%
#create an object of class PorterStemmer
#porter = PorterStemmer()
#lancaster=LancasterStemmer()
#proide a word to be stemmed
#print("Porter Stemmer")
#print(porter.stem("cats"))
#print(porter.stem("trouble"))
#print(porter.stem("troubling"))
#print(porter.stem("troubled"))
#print("Lancaster Stemmer")
#print(lancaster.stem("cats"))
#print(lancaster.stem("trouble"))
#print(lancaster.stem("troubling"))
#print(lancaster.stem("troubled"))

# %%
#filtered_words

# %%
###### I will have to do the following 
## Remove common words 
## Remove Rare words (Based on Word Frequency)

### There are a number of techniques to solve such issues. 
## Try and figure out how to collapse all the lists within that Columns and create a massive word frequency
## might be worth wild to turn the nested list into a dictionary

##################################################################################################
## maybe it is worth wild creating a seperate Relation table which can be joined by the ID?????###
#test = dframetrim['Abstract_trim_2'].to_list()
#### This has turned into a nested list
#test 

#total_word_cnt = 0
#len(test[0])
#len(test)

#### gives you a around 30478 words
#### This seems correct 
#for i in range(len(test)):
#    total_word_cnt += len(test[i])

#flat_list = []
#wordfreq = []
#for sublist in test:
#    for item in sublist:
#        flat_list.append(item)
#len(flat_list)
        
###### It's not working
#list(zip(flat_list, wordfreq))        
#[[x,test[0].count(x)] for x in set(test[0])]

#empty = []
#for x in test[0]:
#    empty = set(test[0].count(x))
#empty
    
#stuff = []
#for id,x in enumerate(test[0]):
#  stuff.append(test[0].count(x))
#   print(stuff)
###############################################
##### Testset - Using the Collections Package #

from collections import Counter
counts = Counter(test[0])
print(counts)

counts.items()

#list(counts.items())[1]
max(counts)

counts.most_common()

total_counts = Counter(flat_list)
unique_counts = total_counts.items()
##### remove stupit and rare words
##### there might be other words that can be add to the list
word_remove_list = ['knowledg','classif','inform','use','www','good','','organ'
                    ,'paper','subject','term','studi','develop','term','librari'
                    ,'differ','index','approach','work','base','scienc','field'
                    ,'user','structure','ko','www','present','ko','also','p',
                    'two','one','provid','author','need','tag','within','way','well','includ',
                   'part','three','may','2','e','ddc','1','3','4','5','6','7','8','9','10','li',
                    'would','non','de','four','ir','thu','frbr','737','g',
                    'etc','av','br','co','th','o','sg','nr','per','1087',
                   'six','j','via','miss','r','et','dan','bia','niac','sch','17525900'
                   'u','lcc','c','ii','la','n','dc','aat' ,'24','TRUE','keep','220','le','po','stw',
                   'kdc','oto','gsc','gsp','k','pt','dr','go','100','cc','il','nt','280','b','l','v',
                   '20','kr','sp','ave','se','12','0','23','33','157','iv','rd','am','mid','34','be','iii','fid'
                    ,'lc','met','20th' ,'ste','axi','dsi','axi','200','230','223','hlt','sur','du','mesh'
                    ,'lcsh','oclc','eu','atn','2nd','bc2','di','76','500','get','http','sdss','crg'
                    ,'esp','sab','lay','11','37','cs','urg','17525000','ot','fo','hn','em','ncft','48',
                    '40','168','dec','pc','fix','ccq','lrt','ic','fix','owe','120th','87','510','94','49',
                    '6n','mit','rev','int','32','136','144','cr','119','148','wall','120','ckm','cd','rom',
                    'ata','nest','sdoc','soli','istei','tct','shl','ana','asp','dk5','240','292','299','f','ég','222'
                    ,'229','59','pin','sen','twelv','bbk','14','28','180','192','cle','150','ec','np','ifla','ey','dea',
                    'cpcl','nl','601','178','215','iskoi','htm','i','ref','31','92','97','çmf','ibn','vo','inv','un','kop','cen','21st'
                    ,'659','ph','229','26','va','oc','ufpr','80060000','ena','od','fu','3d','dog','ear','vi','saa','vi','62',
                    'ed','43hing','kno','pubm','39','268','275','els','fac','nd','ek','oth','er','cep','ia','iti','38','114',
                   '122','35','lam','liu','ru','16','403','41','311','318','ga','eas','gri','tgn','cut','off','add','lrm','cm','ric','collat',
                    'stop','unlik','die','sdi','90','379','1a','1b','rda','riv','hj','pac','hoc','rid','rio','ssn','real',
                   'ccp','iht','edm','today','lie','point','bcc']

dframetrim['Abstract_trim_2'] = dframetrim['Abstract_trim_2'].apply(lambda x: [item for item in x if item not in word_remove_list]) 

####### using this CSV file to check which words to remove from the Abstract_trim_2 col
pd.DataFrame(dframetrim['Lens ID'],)

test = dframetrim['Abstract_trim_2'].to_list()

flat_list = []
wordfreq = []
for sublist in test:
    for item in sublist:
        flat_list.append(item)

total_counts = Counter(flat_list)
unique_counts = total_counts.items()
dsa = total_counts.most_common()
dsalist = pd.DataFrame(list(dsa))
dsalist = dsalist.rename(columns = {0: "Word", 1: "Count"})
dsalist.to_csv(r'C:\Users\andym\Desktop\Datafancy\Journal_managementNP\03-test_datasets\wordcount.csv')
# Out:
# Counter({'t': 1})
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-183-7d6d4b043121> in <module>
#      56 counts.most_common()
#      57
# ---> 58 total_counts = Counter(flat_list)
#      59 unique_counts = total_counts.items()
#      60 ##### remove stupit and rare words
#
# NameError: name 'flat_list' is not defined

# %% [markdown]
# ### Trying to create a seperate table for Words and Word counts

# %%
testing_loop = dframetrim.iloc[0:3,]

testing_loop['abstract_counts'] = [Counter(x).most_common(1) for x in testing_loop['Abstract_trim_2']]
#pd.DataFrame(testing_loop['abstract_counts'], columns=['Word','Count'])
#pd.DataFrame(testing_loop['abstract_counts'])
#pd.DataFrame(list(map(None,testing_loop['abstract_counts'])))
### Interesting Unnesting a Lists
### A list comprehensions
#

testing_loop['abstract_counts_unlist'] = [val for sublist in testing_loop['abstract_counts'] for val in sublist]

#pd.DataFrame(testing_loop['abstract_counts_unlist'])
testing_loop['Word'], testing_loop['Count'] = zip(*testing_loop['abstract_counts_unlist'])
testing_loop['total_Abstract_trim_2'] = testing_loop['Abstract_trim_2'].tolist()

######## 
for i in range(len(testing_loop['total_Abstract_trim_2'])):
        testing_loop['total_Abstract_trim_2'].values[i] = [x for t in testing_loop['Abstract_trim_2'] for x in t]

        ##### Need to do a series of test to see if it is working 
#        for id,i in enumerate(testing_loop['total_Abstract_trim_2']):
#            testing_loop['total_Abstract_trim_2'].values[id].append('knowledg')

testing_loop.to_csv(r'C:\Users\andym\Desktop\Datafancy\Journal_managementNP\03-test_datasets\testing_loopdsa.csv')
       
        
##### this is the last one        
#[item for item in testing_loop['total_Abstract_trim_2'] for x in item] # if item in dframetrim['Abstract_trim_2']]

#testing_loop['total_Abstract_trim_2_list'] = pd.DataFrame()
#for id,item in enumerate(testing_loop['total_Abstract_trim_2']):
#    for i in item:
#        testing_loop['total_Abstract_trim_2_list'].values[id] = i 

#dframetrim['Abstract_trim_2'] = dframetrim['Abstract_trim_2'].apply(lambda x: [item for item in x if item not in stopwords.words('english')])

testing_loop['final_Abstract_trim_2'] = testing_loop['Word']
#testing_loop['total_Abstract_trim_2'].values[2] = ['knowledg']
#testing_loop['Word'].values[2] = 'knowledg'
##### This seems to be working well
for i in range(len(testing_loop['Word'])):
    testing_loop['final_Abstract_trim_2'].values[i] = [item for item in testing_loop['total_Abstract_trim_2'].values[i] if item in testing_loop['Word'].values[i]]
    
#### This needs to be checked
testing_loop.to_csv(r'C:\Users\andym\Desktop\Datafancy\Journal_managementNP\03-test_datasets\testing_loop.csv')

testing_loop['final_Abstract_trim_2'].values[1]
testing_loop['Word'].values[2]


#################################################################################################################
#######   Not Sure if I need this chunck of the code for text preprocessing #####################################
#testing_loop['abstract_counts_all'] = [Counter(x).most_common(1) for x in testing_loop['final_Abstract_trim_2']]
#testing_loop['abstract_counts_unlist_all'] = [val for sublist in testing_loop['abstract_counts_all'] for val in sublist]
#testing_loop['Word_2'], testing_loop['Count_mention_in_all_Abs'] = zip(*testing_loop['abstract_counts_unlist_all'])
#dframetrim['Mentioned_in_all'].apply(lambda x: [item for item in dframetrim['total_Abstract_trim_2'] if item in dframetrim['Abstract_trim_2']])     
#################################################################################################################

testing_loop['abstract_concat_list'] = testing_loop['Abstract_trim_2']
for i in range(len(testing_loop['Abstract_trim_2'])):
    testing_loop['abstract_concat_list'].values[i] = list(testing_loop['Abstract_trim_2'])

testing_loop['dsad'] = testing_loop['abstract_concat_list']
for id1,o in enumerate(testing_loop['abstract_concat_list']):
    for id2,i in enumerate(o):
        testing_loop['dsad'].iloc[id1][id2] = [i for i in testing_loop['abstract_concat_list'].iloc[id1][id2] if i == testing_loop['Word'].values[id1]] 

for id,i in enumerate(testing_loop['dsad']):
    testing_loop['dsad'].values[id] = [x for x in testing_loop['dsad'].values[id] if x != []]        
        
testing_loop['times_mentioned_in_abstracts'] = [len(x) for x in testing_loop['dsad']]

testing_loop["Total_words_in_abstract"] = testing_loop['Abstract_trim_2']
for id,i in enumerate(testing_loop['Abstract_trim_2']):
    testing_loop["Total_words_in_abstract"].iloc[id] = len(testing_loop['Abstract_trim_2'].iloc[id])

testing_loop['Total_number_abstracts'] = len(testing_loop["times_mentioned_in_abstracts"])        
testing_loop['Cal_Term_Freq_TF'] =  testing_loop['Count']/testing_loop["Total_words_in_abstract"]
testing_loop['Cal_Inverse_Document_Freq_IDF'] = np.log(testing_loop['Total_number_abstracts']/testing_loop['times_mentioned_in_abstracts'])


#########################
####    This is to understand the enumera
###########################################################################################
####for id1,o in enumerate(testing_loop['abstract_concat_list']):
####    for id2,i in enumerate(o):         
####        print(id1,id2)

len(testing_loop['Abstract_trim_2'].iloc[0])

testing_loop.to_csv(r'C:\Users\andym\Desktop\Datafancy\Journal_managementNP\03-test_datasets\testing_loop.csv')
# Out:
# C:\Users\andym\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\andym\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# C:\Users\andym\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\andym\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\andym\Anaconda3\lib\site-packages\ipykernel_launcher.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\andym\Anaconda3\lib\site-packages\ipykernel_launcher.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\andym\Anaconda3\lib\site-packages\ipykernel_launcher.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\andym\Anaconda3\lib\site-packages\ipykernel_launcher.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\andym\Anaconda3\lib\site-packages\ipykernel_launcher.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\andym\Anaconda3\lib\site-packages\pandas\core\indexing.py:1636: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\andym\Anaconda3\lib\site-packages\pandas\core\indexing.py:691: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# C:\Users\andym\Anaconda3\lib\site-packages\ipykernel_launcher.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\andym\Anaconda3\lib\site-packages\ipykernel_launcher.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\andym\Anaconda3\lib\site-packages\ipykernel_launcher.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#### This Cell will be populating with the entire Dataset

testing_loop = dframetrim

testing_loop.iloc[0,]

testing_loop['abstract_counts'] = [Counter(x).most_common(1) for x in testing_loop['Abstract_trim_2']]




#pd.DataFrame(testing_loop['abstract_counts'], columns=['Word','Count'])

#pd.DataFrame(testing_loop['abstract_counts'])
#pd.DataFrame(list(map(None,testing_loop['abstract_counts'])))
### Interesting Unnesting a Lists
### A list comprehensions

len(testing_loop['abstract_counts'])

#### We will have to remove rows that have a empty list of strings


##### Within this list there is also a emptylist
##### Those with <p /> Should be removed
testing_loop.to_csv(r'C:\Users\andym\Desktop\Datafancy\Journal_managementNP\03-test_datasets\abstract_counts.csv')


testing_loop = testing_loop[testing_loop.astype(str)['abstract_counts'] != '[]']

### For testing 
#testing_loop[''].iloc[359]

testing_loop['abstract_counts_unlist'] = [val for sublist in dframetrim['abstract_counts'] for val in sublist]

#pd.DataFrame(testing_loop['abstract_counts_unlist'])
testing_loop['Word'], testing_loop['Count'] = zip(*testing_loop['abstract_counts_unlist'])

testing_loop['total_Abstract_trim_2'] = testing_loop['Abstract_trim_2'].tolist()

testing_loop['total_Abstract_trim_2'].values[356] = ['level']

######## 
for i in range(len(testing_loop['total_Abstract_trim_2'])):
        testing_loop['total_Abstract_trim_2'].values[i] = [x for t in testing_loop['Abstract_trim_2'] for x in t]

##### this is the last one        
[[item for item in testing_loop['total_Abstract_trim_2'] for x in item] if item in dframetrim['Abstract_trim_2']]

#testing_loop['total_Abstract_trim_2_list'] = pd.DataFrame()
#for id,item in enumerate(testing_loop['total_Abstract_trim_2']):
#    for i in item:
#        testing_loop['total_Abstract_trim_2_list'].values[id] = i 

#dframetrim['Abstract_trim_2'] = dframetrim['Abstract_trim_2'].apply(lambda x: [item for item in x if item not in stopwords.words('english')])


##### This seems to be working well
#for i in range(len(testing_loop['Word'])):
#    print([item for item in testing_loop['total_Abstract_trim_2'].values[i] if item in testing_loop['Word'].values[i]])
    
#### This needs to be checked
pd.DataFrame(testing_loop).to_csv(r'C:\Users\andym\Desktop\Datafancy\Journal_managementNP\03-test_datasets\testing_loop65ds.csv')

#dframetrim['Mentioned_in_all'].apply(lambda x: [item for item in dframetrim['total_Abstract_trim_2'] if item in dframetrim['Abstract_trim_2']])
# Out:
# C:\Users\andym\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\andym\Anaconda3\lib\site-packages\ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\andym\Anaconda3\lib\site-packages\ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\andym\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-116-f0a2671dda27> in <module>
#      54
#      55 #### This needs to be checked
# ---> 56 testing_loop.to_csv(r'C:\Users\andym\Desktop\Datafancy\Journal_managementNP\03-test_datasets\testing_loop.csv')
#      57
#      58 #dframetrim['Mentioned_in_all'].apply(lambda x: [item for item in dframetrim['total_Abstract_trim_2'] if item in dframetrim['Abstract_trim_2']])
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3398             doublequote=doublequote,
#    3399             escapechar=escapechar,
# -> 3400             storage_options=storage_options,
#    3401         )
#    3402
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1081             formatter=self.fmt,
#    1082         )
# -> 1083         csv_formatter.save()
#    1084
#    1085         if created_buffer:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     232             errors=self.errors,
#     233             compression=self.compression,
# --> 234             storage_options=self.storage_options,
#     235         ) as handles:
#     236
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     642                 encoding=ioargs.encoding,
#     643                 errors=errors,
# --> 644                 newline="",
#     645             )
#     646         else:
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\andym\\Desktop\\Datafancy\\Journal_managementNP\\03-test_datasets\\testing_loop.csv'

# %%
testing_loop_2 = dframetrim.iloc[0:3,]


testing_loop_2['Abstract_trim_2'] = testing_loop_2['Abstract_trim_2'].apply(lambda x: [item for item in x if item not in word_remove_list])

# %% [markdown]
# #### Going to make an attempt to create word count frequencies

# %% [markdown]
# ###### Currently under progress

# %%
#### attempt to making the new word count frequencies 
#### Might need to learn some pandas
### https://www.geeksforgeeks.org/counting-the-frequencies-in-a-list-using-dictionary-in-python/
### NOT MAKING ALOT OF PROGRESS
from collections import Counter 
 
def group_list(lst): 
      
    return list(zip(Counter(lst).keys(), Counter(lst).values())) 

#group_list(testing_loop['Abstract_trim_2'])
dframetrim 

dframetrim['Abstract_trim_2'].values[0]
dframetrim.values[0].groupby(['Abstract_trim_2']).count()
testdframetrim = dframetrim['Abstract_trim_2']
dftest = testdframetrim.values[0].count(testdframetrim.values[0])

test = group_list(dftest)
test[:,2]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-3c43f327a639> in <module>
#      11
#      12 dframetrim['Abstract_trim_2'].values[0]
# ---> 13 dframetrim.values[0].groupby(['Abstract_trim_2']).count()
#      14
#      15 testdframetrim = dframetrim['Abstract_trim_2']
#
# AttributeError: 'numpy.ndarray' object has no attribute 'groupby'

# %%
dframetrim.to_csv(r'C:\Users\andym\Desktop\Datafancy\Journal_managementNP\03-test_datasets\test.csv')

# %%
len(dframetrim['Abstract'])
# Out:
# 360
